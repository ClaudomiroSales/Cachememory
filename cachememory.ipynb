# %% [markdown]
# Fazer um programa no Jupyter adaptando o programa da memória principal anteriormente implementado e fazer a MP ter a mesma configuração da figura abaixo: 32 células com endereços de 5 bits. A memória cache terá 4 linhas como indicado na figura. As duas memórias podem ser representadas como arrays.

# %% [markdown]
# O programa deve ter uma função (def) cacheController que captura (recebe como argumento) um endereço e o quebra como mostrado na figura para determinar se um bloco está na cache. Para isso, aplicar o método direto.

# %%
#Veja que está incompleto o programa abaixo. A função cacheController está sem argumento (sem o endereço) 
#e não tem nada nela, e 
#não se está imprimindo o conteúdo da célula.

#Manter no projeto final a função runSimulation e fazer tudo dentro dela. Ela recebe todos os argumentos 
#e redistribui para as outras funções
#Antes de chamá-la, peçam ao usuário (processador) o endereço a ser usado.

def cacheController( ):
    return False; #trocar para True e False para simular os dois casos. Mas na implementação de vocês aplicar método direto
def runSimulation( ):
    if cacheController( ):
        print("Bloco encontrado. Hit")
        print("Conteúdo da célula: xxxxxx")
        return
    #Early return - não uso else
    print("Bloco não encontrado. Miss.")
    #A partir daqui você precisa chamar uma def que vai buscar o bloco na MP e atualizar na linha
    #correspondente na MP considerando que é método direto
    
    
runSimulation( )
# Out:
# Bloco não encontrado. Miss.

# %% [raw]
# Antes de começar a simulação preenche automaticamente a MP com valores binários diferentes de zero.
# Ou seja, 00000 -> 00010110
#          00001 -> 10110111
#          e assim por diante
# Podem ser valores aleatórios ou escolhidos por vocês.

# %%
from IPython.display import Image



Image(filename='SistemaCacheMP.png')
